# %%
# Create Latitude and Longitude Combinations
# imprt the dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Add the code that generates the latitudes and longitudes

# use zip()object to pack the lats and lng,The zip object packs each pair of 
# lats and lngs having the same index in their respective array into a tuple. 
# If there are 1,500 latitudes and longitudes, there will be 1,500 tuples of paired 
# latitudes and longitudes,

# create a set of random latitudes and longitudes combinations
lats =np.random.uniform(low=-90.000, high=90.000, size=8000)
lngs =np.random.uniform(low=-180.00, high=1800, size=8000)
lats_lngs = zip(lats, lngs)

# %%
# Next, let’s unpack our lat_lngs zip object into a list. This way, we only need 
# to create a set of random latitudes and longitudes once
# Add the latitudes and longtitudes to a list
coordinates = list(lats_lngs)

# %%
# Next, use the five pairs of latitudes and longitudes we used from our zip practice to get a 
# city and country code from the citipy module.

from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
# Create a list for holding the cities.
cities = [] # stores city names
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates: # iterate through coordinates to retrieve nearest city
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities: # determines whether the found city is in cities
        cities.append(city) #if not found, we use append() to find it
# Print the city count to confirm sufficient count.
len(cities)

# When you run the code block, you should get slightly more than 500 unique cities. 
# If you get fewer than 500, increase your size limit on the np.random.uniform() function.
# Out:
# 641

# %%
# For each city in our lats_lngs list,retrieve the following data and add it to a DataFrame:
# City, country, and date
# Latitude and longitude
# Maximum temperature
# Humidity
# Cloudiness
# Wind speed

# Before we collect weather data from more than 500 cities, we’ll walk through how to 
# get the weather data from Boston.

# %%
# import the Requests Library and your API key from the config.py file.
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=98e7bcbbdfd9e516604879f5d2a923ea

# %%
# In the code, we are creating a string to get the weather data for Boston by using the city_url. 
# To create the city_url we add the parameter, &q= and “Boston” to the url.
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=98e7bcbbdfd9e516604879f5d2a923ea&q=Boston

# %%
# Use the get() method, a feature of the Requests Library, to request data from an API. 
# The get() method is one of many HTTP methods that allow us to access, add, delete, get the headers, 
# and perform other actions on the request.

# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather.status_code
# Out:
# 200

# %%
# Before we collect weather data from more than 500 cities, we’ll walk through how to get the 
# weather data from Boston
# the output will be the JSON-formatted data from the city of Boston

# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.06, 'lat': 42.36},
#  'weather': [{'id': 500,
#    'main': 'Rain',
#    'description': 'light rain',
#    'icon': '10d'},
#   {'id': 701, 'main': 'Mist', 'description': 'mist', 'icon': '50d'}],
#  'base': 'stations',
#  'main': {'temp': 39.24,
#   'feels_like': 25.57,
#   'temp_min': 37,
#   'temp_max': 41,
#   'pressure': 1017,
#   'humidity': 93},
#  'visibility': 2414,
#  'wind': {'speed': 19.46, 'deg': 80},
#  'rain': {'1h': 0.7},
#  'clouds': {'all': 90},
#  'dt': 1585522582,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1585477854,
#   'sunset': 1585523190},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# To check if we get a valid response, we can write a conditional expression that will evaluate 
# whether the status code is equal to 200. If it is, then we can print out a statement that says 
# the weather data was found. If there is a response other than 200, we can print out a statement 
# that says the weather was not found,

#  Handle Request Errors
# Create an endpoint URL for a city.
city_url = url + "&q=" + "New York"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# 1- Next let’s assign a variable to the city_weather.json() data to the variable 
# “boston_data” and run the cell.

# %%
# Get the JSON data.
boston_data = city_weather.json()
boston_data
# Out:
# {'coord': {'lon': -74.01, 'lat': 40.71},
#  'weather': [{'id': 701,
#    'main': 'Mist',
#    'description': 'mist',
#    'icon': '50d'}],
#  'base': 'stations',
#  'main': {'temp': 46.63,
#   'feels_like': 36.97,
#   'temp_min': 44.6,
#   'temp_max': 48.99,
#   'pressure': 1012,
#   'humidity': 93},
#  'visibility': 4828,
#  'wind': {'speed': 14.99, 'deg': 40, 'gust': 18.34},
#  'clouds': {'all': 90},
#  'dt': 1585522155,
#  'sys': {'type': 1,
#   'id': 4610,
#   'country': 'US',
#   'sunrise': 1585478613,
#   'sunset': 1585523846},
#  'timezone': -14400,
#  'id': 5128581,
#  'name': 'New York',
#  'cod': 200}

# %%
# 2 -Next, using the sys key to get the corresponding value, we type boston_data['sys']in 
# a new cell and run the cell. The output is another dictionary as shown in the following image. 
boston_data["sys"]
# Out:
# {'type': 1,
#  'id': 4610,
#  'country': 'US',
#  'sunrise': 1585478613,
#  'sunset': 1585523846}

# %%
# 3- If we add the country key in brackets after the sys key, and run the cell again, 
# ‘US’ will be returned in the output.

boston_data["sys"]["country"]
# Out:
# 'US'

# %%
# When we used boston_data["sys"], there was a key for sunrise and a key for sunset in the output. 
# The value for these keys is the time of day in seconds in a database timestamp format.

# If we want to retrieve the date in the weather data, we would add the dt key to the boston_data 
# variable like this: boston_data["dt"].

boston_data["dt"]
# Out:
# 1585522155

# %%
# Get the latitude value from the Boston JSON data
boston_data["coord"]["lat"]
# Out:
# 40.71

# %%
# Get the maximum temperature value from the Boston JSON data
boston_data["main"]["temp_max"]
# Out:
# 48.99

# %%
# Using similar syntax to get the time of day
# Get the latitude, longitude, maximum temperature, 
# Get the humidity, percent cloudiness, and wind speed.

lat = boston_data["coord"]["lat"]
lng = boston_data["coord"]["lon"]
max_temp = boston_data["main"]["temp_max"]
humidity = boston_data["main"]["humidity"]
clouds = boston_data["clouds"]["all"]
wind = boston_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 40.71 -74.01 48.99 93 90 14.99

# %%
# Let’s convert the date from the Boston weather data in the JSON format to the ISO format.

# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = boston_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date)
# Out:
# datetime.datetime(2020, 3, 29, 22, 49, 15)

# %%
# We can convert this datetime format to 2019-08-08 15:47:30 using the Python string 
# format method strftime() and adding how we want the string to look inside the parentheses. 
# In our case, we would use strftime('%Y-%m-%d %H:%M:%S').

# %%
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2020-03-29 22:49:15'

# %%
# Get the City Weather Data 
# Let’s use pseudocode to map out, at a high level, how we will get the weather data for each city for the website.

# We will need to do the following:
# Import our dependencies and initialize counters and an empty list that will hold the weather data.
# Loop through the cities list.
# Group the cities in sets of 50 to log the process as we find the weather data for each city.
# Two counters will be needed here: one to log the city count from 1 to 50, and another for the sets.
# Build the city_url or endpoint for each city.
# Log the URL and the record and set numbers.
# Make an API request for each city.
# Parse the JSON weather data for the following:
# City, country, and date
# Latitude and longitude
# Maximum temperature
# Humidity
# Cloudiness
# Wind speed
# add the data to a list in a dictionary format and then convert the list to a DataFrame.

# %%
# Import Dependencies, and Initialize an Empty List and Counters
# At the top of our code block, we are going to declare an empty list, city_data = []; add a print statement that references the beginning of the logging; and create counters for the record numbers, 1–50; and the set counter.
# Before adding new code to our WeatherPy file, make sure the following tasks are completed:
# Import your Requests Library and the weather_api_key.
# Build the basic URL for the OpenWeatherMap with your weather_api_key added to the URL.
# Also, import the datetime module using the following code:

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
# In the code block, we have initialized the counters at 1 because we want the first iteration 
# of the logging for each recorded response and the set to start at 1.

city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
#-------------------------------------------------------------------------------------------
# Loop Through the List of Cities and Build the City URL

# Next, we need to iterate through our list of cities and begin building the URL for each city, 
# while grouping our records in sets of 50

# Loop through all the cities in the list.
# we can use the enumerate() method as an alternative way to iterate through the list of cities
# and retrieve both the index, and the city from the list

for i, city in enumerate(cities):

# Group cities in sets of 50 for logging purposes.
# In the conditional statement, we check if the remainder of the index divided by 50 is equal 
# to 0 and if the index is greater than or equal to 50. If the statement is true, 
# then the set_count and the record_count are equal to 1
   
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

# Log the URL, record, and set numbers and the city.
# add a print statement that tells us the record count and set count, and the city 
# that is being processe
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | asau
# Processing Record 2 of Set 1 | chuy
# Processing Record 3 of Set 1 | khatanga
# Processing Record 4 of Set 1 | beringovskiy
# Processing Record 5 of Set 1 | tsihombe
# Processing Record 6 of Set 1 | ibra
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | comodoro rivadavia
# Processing Record 9 of Set 1 | port-gentil
# Processing Record 10 of Set 1 | provideniya
# Processing Record 11 of Set 1 | ruatoria
# Processing Record 12 of Set 1 | muros
# Processing Record 13 of Set 1 | cape town
# Processing Record 14 of Set 1 | oktyabrskiy
# Processing Record 15 of Set 1 | leningradskiy
# Processing Record 16 of Set 1 | zolotinka
# Processing Record 17 of Set 1 | arraial do cabo
# Processing Record 18 of Set 1 | sorong
# Processing Record 19 of Set 1 | tolaga bay
# Processing Record 20 of Set 1 | saint-pierre
# Processing Record 21 of Set 1 | aksu
# Processing Record 22 of Set 1 | waipawa
# Processing Record 23 of Set 1 | tiksi
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | longyearbyen
# Processing Record 26 of Set 1 | barrow
# Processing Record 27 of Set 1 | port hardy
# Processing Record 28 of Set 1 | egersund
# Processing Record 29 of Set 1 | mahebourg
# Processing Record 30 of Set 1 | doctor arroyo
# Processing Record 31 of Set 1 | dauphin
# Processing Record 32 of Set 1 | ambon
# Processing Record 33 of Set 1 | broome
# Processing Record 34 of Set 1 | cayenne
# Processing Record 35 of Set 1 | carnarvon
# Processing Record 36 of Set 1 | tuktoyaktuk
# Processing Record 37 of Set 1 | tasiilaq
# Processing Record 38 of Set 1 | satitoa
# Processing Record 39 of Set 1 | chamrajnagar
# Processing Record 40 of Set 1 | san carlos de bariloche
# Processing Record 41 of Set 1 | albany
# Processing Record 42 of Set 1 | busselton
# Processing Record 43 of Set 1 | champasak
# Processing Record 44 of Set 1 | sentyabrskiy
# Processing Record 45 of Set 1 | kaitangata
# Processing Record 46 of Set 1 | ribeira grande
# Processing Record 47 of Set 1 | taolanaro
# Processing Record 48 of Set 1 | ushuaia
# Processing Record 49 of Set 1 | mar del plata
# Processing Record 50 of Set 1 | urubicha
# Processing Record 1 of Set 2 | chagda
# Processing Record 2 of Set 2 | tamandare
# Processing Record 3 of Set 2 | kodiak
# Processing Record 4 of Set 2 | chokurdakh
# Processing Record 5 of Set 2 | victoria
# Processing Record 6 of Set 2 | walvis bay
# Processing Record 7 of Set 2 | butaritari
# Processing Record 8 of Set 2 | tezu
# Processing Record 9 of Set 2 | qaanaaq
# Processing Record 10 of Set 2 | chivay
# Processing Record 11 of Set 2 | punta arenas
# Processing Record 12 of Set 2 | mayumba
# Processing Record 13 of Set 2 | hermanus
# Processing Record 14 of Set 2 | dikson
# Processing Record 15 of Set 2 | le port
# Processing Record 16 of Set 2 | port alfred
# Processing Record 17 of Set 2 | atuona
# Processing Record 18 of Set 2 | kiruna
# Processing Record 19 of Set 2 | rapu-rapu
# Processing Record 20 of Set 2 | nikolskoye
# Processing Record 21 of Set 2 | santa cruz de la palma
# Processing Record 22 of Set 2 | bambous virieux
# Processing Record 23 of Set 2 | llangefni
# Processing Record 24 of Set 2 | wanning
# Processing Record 25 of Set 2 | boa esperanca
# Processing Record 26 of Set 2 | gimli
# Processing Record 27 of Set 2 | bethel
# Processing Record 28 of Set 2 | bat khela
# Processing Record 29 of Set 2 | mataura
# Processing Record 30 of Set 2 | illoqqortoormiut
# Processing Record 31 of Set 2 | puerto ayora
# Processing Record 32 of Set 2 | pevek
# Processing Record 33 of Set 2 | fredericton
# Processing Record 34 of Set 2 | nelson bay
# Processing Record 35 of Set 2 | kodinar
# Processing Record 36 of Set 2 | coihaique
# Processing Record 37 of Set 2 | saldanha
# Processing Record 38 of Set 2 | ilulissat
# Processing Record 39 of Set 2 | matara
# Processing Record 40 of Set 2 | upernavik
# Processing Record 41 of Set 2 | te anau
# Processing Record 42 of Set 2 | bayanday
# Processing Record 43 of Set 2 | kapaa
# Processing Record 44 of Set 2 | norman wells
# Processing Record 45 of Set 2 | jamestown
# Processing Record 46 of Set 2 | itoman
# Processing Record 47 of Set 2 | cidreira
# Processing Record 48 of Set 2 | touros
# Processing Record 49 of Set 2 | rungata
# Processing Record 50 of Set 2 | huarmey
# Processing Record 1 of Set 3 | coaticook
# Processing Record 2 of Set 3 | juifang
# Processing Record 3 of Set 3 | bredasdorp
# Processing Record 4 of Set 3 | vila
# Processing Record 5 of Set 3 | vaini
# Processing Record 6 of Set 3 | zhigansk
# Processing Record 7 of Set 3 | hobart
# Processing Record 8 of Set 3 | cuajinicuilapa
# Processing Record 9 of Set 3 | avarua
# Processing Record 10 of Set 3 | castro
# Processing Record 11 of Set 3 | slidell
# Processing Record 12 of Set 3 | faanui
# Processing Record 13 of Set 3 | arlit
# Processing Record 14 of Set 3 | nanortalik
# Processing Record 15 of Set 3 | cabo san lucas
# Processing Record 16 of Set 3 | high level
# Processing Record 17 of Set 3 | moose factory
# Processing Record 18 of Set 3 | coracora
# Processing Record 19 of Set 3 | prnjavor
# Processing Record 20 of Set 3 | borlange
# Processing Record 21 of Set 3 | yellowknife
# Processing Record 22 of Set 3 | antofagasta
# Processing Record 23 of Set 3 | barrhead
# Processing Record 24 of Set 3 | meyungs
# Processing Record 25 of Set 3 | tarpon springs
# Processing Record 26 of Set 3 | bahia honda
# Processing Record 27 of Set 3 | falealupo
# Processing Record 28 of Set 3 | thanh hoa
# Processing Record 29 of Set 3 | port elizabeth
# Processing Record 30 of Set 3 | san quintin
# Processing Record 31 of Set 3 | srednekolymsk
# Processing Record 32 of Set 3 | skjervoy
# Processing Record 33 of Set 3 | kununurra
# Processing Record 34 of Set 3 | mys shmidta
# Processing Record 35 of Set 3 | helong
# Processing Record 36 of Set 3 | grand river south east
# Processing Record 37 of Set 3 | amderma
# Processing Record 38 of Set 3 | fort erie
# Processing Record 39 of Set 3 | namibe
# Processing Record 40 of Set 3 | barentsburg
# Processing Record 41 of Set 3 | ratnagiri
# Processing Record 42 of Set 3 | rangpur
# Processing Record 43 of Set 3 | airai
# Processing Record 44 of Set 3 | hithadhoo
# Processing Record 45 of Set 3 | kaeo
# Processing Record 46 of Set 3 | petukhovo
# Processing Record 47 of Set 3 | bluff
# Processing Record 48 of Set 3 | geraldton
# Processing Record 49 of Set 3 | lagoa
# Processing Record 50 of Set 3 | saint george
# Processing Record 1 of Set 4 | coquimbo
# Processing Record 2 of Set 4 | ardee
# Processing Record 3 of Set 4 | vanimo
# Processing Record 4 of Set 4 | chern
# Processing Record 5 of Set 4 | pisco
# Processing Record 6 of Set 4 | havre-saint-pierre
# Processing Record 7 of Set 4 | acandi
# Processing Record 8 of Set 4 | clyde river
# Processing Record 9 of Set 4 | hokitika
# Processing Record 10 of Set 4 | bogorodskoye
# Processing Record 11 of Set 4 | tiznit
# Processing Record 12 of Set 4 | meiringen
# Processing Record 13 of Set 4 | talnakh
# Processing Record 14 of Set 4 | chibuto
# Processing Record 15 of Set 4 | poum
# Processing Record 16 of Set 4 | lebu
# Processing Record 17 of Set 4 | jabiru
# Processing Record 18 of Set 4 | taunggyi
# Processing Record 19 of Set 4 | tynda
# Processing Record 20 of Set 4 | punta alta
# Processing Record 21 of Set 4 | pangoa
# Processing Record 22 of Set 4 | kilindoni
# Processing Record 23 of Set 4 | manassas
# Processing Record 24 of Set 4 | hamadan
# Processing Record 25 of Set 4 | sao miguel do araguaia
# Processing Record 26 of Set 4 | beipiao
# Processing Record 27 of Set 4 | kansanshi
# Processing Record 28 of Set 4 | saint-gaudens
# Processing Record 29 of Set 4 | dubai
# Processing Record 30 of Set 4 | severo-yeniseyskiy
# Processing Record 31 of Set 4 | urdoma
# Processing Record 32 of Set 4 | concordia
# Processing Record 33 of Set 4 | miami
# Processing Record 34 of Set 4 | pinega
# Processing Record 35 of Set 4 | daru
# Processing Record 36 of Set 4 | fortuna
# Processing Record 37 of Set 4 | belushya guba
# Processing Record 38 of Set 4 | isangel
# Processing Record 39 of Set 4 | great falls
# Processing Record 40 of Set 4 | dunedin
# Processing Record 41 of Set 4 | teahupoo
# Processing Record 42 of Set 4 | khorixas
# Processing Record 43 of Set 4 | nyandoma
# Processing Record 44 of Set 4 | nguiu
# Processing Record 45 of Set 4 | shevchenkove
# Processing Record 46 of Set 4 | hamilton
# Processing Record 47 of Set 4 | tukrah
# Processing Record 48 of Set 4 | codrington
# Processing Record 49 of Set 4 | labuhan
# Processing Record 50 of Set 4 | husavik
# Processing Record 1 of Set 5 | cocobeach
# Processing Record 2 of Set 5 | turukhansk
# Processing Record 3 of Set 5 | abbeville
# Processing Record 4 of Set 5 | banda aceh
# Processing Record 5 of Set 5 | iqaluit
# Processing Record 6 of Set 5 | atambua
# Processing Record 7 of Set 5 | sinkat
# Processing Record 8 of Set 5 | bara
# Processing Record 9 of Set 5 | wanaka
# Processing Record 10 of Set 5 | karamea
# Processing Record 11 of Set 5 | masuguru
# Processing Record 12 of Set 5 | antiguo morelos
# Processing Record 13 of Set 5 | esperance
# Processing Record 14 of Set 5 | moroni
# Processing Record 15 of Set 5 | teneguiban
# Processing Record 16 of Set 5 | indiana
# Processing Record 17 of Set 5 | baraki barak
# Processing Record 18 of Set 5 | tahta
# Processing Record 19 of Set 5 | morlaix
# Processing Record 20 of Set 5 | tombouctou
# Processing Record 21 of Set 5 | salinopolis
# Processing Record 22 of Set 5 | madras
# Processing Record 23 of Set 5 | saint-louis
# Processing Record 24 of Set 5 | chachapoyas
# Processing Record 25 of Set 5 | tessalit
# Processing Record 26 of Set 5 | beyneu
# Processing Record 27 of Set 5 | konskie
# Processing Record 28 of Set 5 | nishihara
# Processing Record 29 of Set 5 | nichinan
# Processing Record 30 of Set 5 | louisbourg
# Processing Record 31 of Set 5 | pietarsaari
# Processing Record 32 of Set 5 | yerbogachen
# Processing Record 33 of Set 5 | new norfolk
# Processing Record 34 of Set 5 | viedma
# Processing Record 35 of Set 5 | margate
# Processing Record 36 of Set 5 | campo grande
# Processing Record 37 of Set 5 | shushenskoye
# Processing Record 38 of Set 5 | assare
# Processing Record 39 of Set 5 | tlahualilo
# Processing Record 40 of Set 5 | paamiut
# Processing Record 41 of Set 5 | manzhouli
# Processing Record 42 of Set 5 | eureka
# Processing Record 43 of Set 5 | sandwich
# Processing Record 44 of Set 5 | richards bay
# Processing Record 45 of Set 5 | marienburg
# Processing Record 46 of Set 5 | athabasca
# Processing Record 47 of Set 5 | puerto escondido
# Processing Record 48 of Set 5 | holme
# Processing Record 49 of Set 5 | qafsah
# Processing Record 50 of Set 5 | alice springs
# Processing Record 1 of Set 6 | plettenberg bay
# Processing Record 2 of Set 6 | verkhnevilyuysk
# Processing Record 3 of Set 6 | ormara
# Processing Record 4 of Set 6 | san matias
# Processing Record 5 of Set 6 | tabas
# Processing Record 6 of Set 6 | hobyo
# Processing Record 7 of Set 6 | dingle
# Processing Record 8 of Set 6 | great bend
# Processing Record 9 of Set 6 | saint-philippe
# Processing Record 10 of Set 6 | colchester
# Processing Record 11 of Set 6 | vao
# Processing Record 12 of Set 6 | torbay
# Processing Record 13 of Set 6 | carbonia
# Processing Record 14 of Set 6 | georgetown
# Processing Record 15 of Set 6 | kobelyaky
# Processing Record 16 of Set 6 | poya
# Processing Record 17 of Set 6 | broken hill
# Processing Record 18 of Set 6 | portland
# Processing Record 19 of Set 6 | bumba
# Processing Record 20 of Set 6 | gisborne
# Processing Record 21 of Set 6 | haines junction
# Processing Record 22 of Set 6 | elmira
# Processing Record 23 of Set 6 | sisimiut
# Processing Record 24 of Set 6 | thompson
# Processing Record 25 of Set 6 | sept-iles
# Processing Record 26 of Set 6 | flinders
# Processing Record 27 of Set 6 | skalistyy
# Processing Record 28 of Set 6 | kilakarai
# Processing Record 29 of Set 6 | ketchikan
# Processing Record 30 of Set 6 | east london
# Processing Record 31 of Set 6 | tuatapere
# Processing Record 32 of Set 6 | la ronge
# Processing Record 33 of Set 6 | gat
# Processing Record 34 of Set 6 | buraydah
# Processing Record 35 of Set 6 | bolshoye polpino
# Processing Record 36 of Set 6 | damghan
# Processing Record 37 of Set 6 | saint anthony
# Processing Record 38 of Set 6 | paka
# Processing Record 39 of Set 6 | tumannyy
# Processing Record 40 of Set 6 | palabuhanratu
# Processing Record 41 of Set 6 | turayf
# Processing Record 42 of Set 6 | trinidad
# Processing Record 43 of Set 6 | nigde
# Processing Record 44 of Set 6 | rocha
# Processing Record 45 of Set 6 | narsaq
# Processing Record 46 of Set 6 | gushikawa
# Processing Record 47 of Set 6 | cabedelo
# Processing Record 48 of Set 6 | kloulklubed
# Processing Record 49 of Set 6 | tabulbah
# Processing Record 50 of Set 6 | mastic beach
# Processing Record 1 of Set 7 | tabuk
# Processing Record 2 of Set 7 | otavi
# Processing Record 3 of Set 7 | nemuro
# Processing Record 4 of Set 7 | buzdyak
# Processing Record 5 of Set 7 | tanete
# Processing Record 6 of Set 7 | vanavara
# Processing Record 7 of Set 7 | copiapo
# Processing Record 8 of Set 7 | saint-vallier
# Processing Record 9 of Set 7 | tulsa
# Processing Record 10 of Set 7 | banikoara
# Processing Record 11 of Set 7 | fairbanks
# Processing Record 12 of Set 7 | mtwango
# Processing Record 13 of Set 7 | tarudant
# Processing Record 14 of Set 7 | bedele
# Processing Record 15 of Set 7 | finschhafen
# Processing Record 16 of Set 7 | harqalah
# Processing Record 17 of Set 7 | blonduos
# Processing Record 18 of Set 7 | saint-augustin
# Processing Record 19 of Set 7 | saryozek
# Processing Record 20 of Set 7 | karratha
# Processing Record 21 of Set 7 | cape girardeau
# Processing Record 22 of Set 7 | alofi
# Processing Record 23 of Set 7 | krasnyy chikoy
# Processing Record 24 of Set 7 | dunmore town
# Processing Record 25 of Set 7 | brae
# Processing Record 26 of Set 7 | kuytun
# Processing Record 27 of Set 7 | phonhong
# Processing Record 28 of Set 7 | makung
# Processing Record 29 of Set 7 | luderitz
# Processing Record 30 of Set 7 | terra roxa
# Processing Record 31 of Set 7 | monte patria
# Processing Record 32 of Set 7 | arman
# Processing Record 33 of Set 7 | olinda
# Processing Record 34 of Set 7 | botwood
# Processing Record 35 of Set 7 | beloha
# Processing Record 36 of Set 7 | bluefield
# Processing Record 37 of Set 7 | avila
# Processing Record 38 of Set 7 | tsabong
# Processing Record 39 of Set 7 | umzimvubu
# Processing Record 40 of Set 7 | saskylakh
# Processing Record 41 of Set 7 | artesia
# Processing Record 42 of Set 7 | fort nelson
# Processing Record 43 of Set 7 | ponta do sol
# Processing Record 44 of Set 7 | seeheim-jugenheim
# Processing Record 45 of Set 7 | gejiu
# Processing Record 46 of Set 7 | hasaki
# Processing Record 47 of Set 7 | sao joao da barra
# Processing Record 48 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 7 | krasnoselkup
# Processing Record 50 of Set 7 | singapore
# Processing Record 1 of Set 8 | kungurtug
# Processing Record 2 of Set 8 | souillac
# Processing Record 3 of Set 8 | nouakchott
# Processing Record 4 of Set 8 | xicotencatl
# Processing Record 5 of Set 8 | qabaqcol
# Processing Record 6 of Set 8 | marawi
# Processing Record 7 of Set 8 | vila franca do campo
# Processing Record 8 of Set 8 | kochubey
# Processing Record 9 of Set 8 | attawapiskat
# Processing Record 10 of Set 8 | tarrafal
# Processing Record 11 of Set 8 | vestmanna
# Processing Record 12 of Set 8 | bengkulu
# Processing Record 13 of Set 8 | naryan-mar
# Processing Record 14 of Set 8 | boa vista
# Processing Record 15 of Set 8 | bolshaya dzhalga
# Processing Record 16 of Set 8 | palaikastron
# Processing Record 17 of Set 8 | pahrump
# Processing Record 18 of Set 8 | tucurui
# Processing Record 19 of Set 8 | vesyegonsk
# Processing Record 20 of Set 8 | kurchum
# Processing Record 21 of Set 8 | nicoya
# Processing Record 22 of Set 8 | manadhoo
# Processing Record 23 of Set 8 | chapais
# Processing Record 24 of Set 8 | lompoc
# Processing Record 25 of Set 8 | cherskiy
# Processing Record 26 of Set 8 | komsomolskiy
# Processing Record 27 of Set 8 | saleaula
# Processing Record 28 of Set 8 | jati
# Processing Record 29 of Set 8 | novopavlovsk
# Processing Record 30 of Set 8 | caravelas
# Processing Record 31 of Set 8 | zyryanovsk
# Processing Record 32 of Set 8 | issia
# Processing Record 33 of Set 8 | zholymbet
# Processing Record 34 of Set 8 | mehamn
# Processing Record 35 of Set 8 | bom jesus
# Processing Record 36 of Set 8 | ulundi
# Processing Record 37 of Set 8 | mega
# Processing Record 38 of Set 8 | juliaca
# Processing Record 39 of Set 8 | kavieng
# Processing Record 40 of Set 8 | almeirim
# Processing Record 41 of Set 8 | khem karan
# Processing Record 42 of Set 8 | vardo
# Processing Record 43 of Set 8 | kassala
# Processing Record 44 of Set 8 | hermiston
# Processing Record 45 of Set 8 | aksarka
# Processing Record 46 of Set 8 | methoni
# Processing Record 47 of Set 8 | lask
# Processing Record 48 of Set 8 | san cristobal
# Processing Record 49 of Set 8 | college
# Processing Record 50 of Set 8 | long beach
# Processing Record 1 of Set 9 | ossora
# Processing Record 2 of Set 9 | verkhoyansk
# Processing Record 3 of Set 9 | kovur
# Processing Record 4 of Set 9 | amvrosiyivka
# Processing Record 5 of Set 9 | samara
# Processing Record 6 of Set 9 | san patricio
# Processing Record 7 of Set 9 | noyabrsk
# Processing Record 8 of Set 9 | kirakira
# Processing Record 9 of Set 9 | benguela
# Processing Record 10 of Set 9 | dukat
# Processing Record 11 of Set 9 | chumikan
# Processing Record 12 of Set 9 | sorvag
# Processing Record 13 of Set 9 | aranos
# Processing Record 14 of Set 9 | uruguaiana
# Processing Record 15 of Set 9 | boyle
# Processing Record 16 of Set 9 | taoudenni
# Processing Record 17 of Set 9 | manokwari
# Processing Record 18 of Set 9 | aparecida do taboado
# Processing Record 19 of Set 9 | eresos
# Processing Record 20 of Set 9 | tazovskiy
# Processing Record 21 of Set 9 | veraval
# Processing Record 22 of Set 9 | ostrovnoy
# Processing Record 23 of Set 9 | rio grande
# Processing Record 24 of Set 9 | ejido
# Processing Record 25 of Set 9 | at-bashi
# Processing Record 26 of Set 9 | zeya
# Processing Record 27 of Set 9 | kaihua
# Processing Record 28 of Set 9 | bowen
# Processing Record 29 of Set 9 | prado
# Processing Record 30 of Set 9 | jalpan
# Processing Record 31 of Set 9 | deputatskiy
# Processing Record 32 of Set 9 | rantepao
# Processing Record 33 of Set 9 | san jose
# Processing Record 34 of Set 9 | taltal
# Processing Record 35 of Set 9 | gushi
# Processing Record 36 of Set 9 | kiama
# Processing Record 37 of Set 9 | perth
# Processing Record 38 of Set 9 | lolua
# Processing Record 39 of Set 9 | port hedland
# Processing Record 40 of Set 9 | ulladulla
# Processing Record 41 of Set 9 | dongsheng
# Processing Record 42 of Set 9 | vila velha
# Processing Record 43 of Set 9 | hoyanger
# Processing Record 44 of Set 9 | rognan
# Processing Record 45 of Set 9 | wajima
# Processing Record 46 of Set 9 | teknaf
# Processing Record 47 of Set 9 | natal
# Processing Record 48 of Set 9 | dmitriyevka
# Processing Record 49 of Set 9 | mora
# Processing Record 50 of Set 9 | yanam
# Processing Record 1 of Set 10 | hessisch lichtenau
# Processing Record 2 of Set 10 | athens
# Processing Record 3 of Set 10 | sjenica
# Processing Record 4 of Set 10 | lavrentiya
# Processing Record 5 of Set 10 | malanje
# Processing Record 6 of Set 10 | xuddur
# Processing Record 7 of Set 10 | ust-ishim
# Processing Record 8 of Set 10 | mount gambier
# Processing Record 9 of Set 10 | kulhudhuffushi
# Processing Record 10 of Set 10 | tura
# Processing Record 11 of Set 10 | westport
# Processing Record 12 of Set 10 | tabarqah
# Processing Record 13 of Set 10 | inhambane
# Processing Record 14 of Set 10 | saint andrews
# Processing Record 15 of Set 10 | port lincoln
# Processing Record 16 of Set 10 | henties bay
# Processing Record 17 of Set 10 | bilma
# Processing Record 18 of Set 10 | buala
# Processing Record 19 of Set 10 | lethem
# Processing Record 20 of Set 10 | malwan
# Processing Record 21 of Set 10 | mildura
# Processing Record 22 of Set 10 | peniche
# Processing Record 23 of Set 10 | atar
# Processing Record 24 of Set 10 | belyy yar
# Processing Record 25 of Set 10 | yakeshi
# Processing Record 26 of Set 10 | samusu
# Processing Record 27 of Set 10 | grand gaube
# Processing Record 28 of Set 10 | shache
# Processing Record 29 of Set 10 | bolungarvik
# Processing Record 30 of Set 10 | kaeng khoi
# Processing Record 31 of Set 10 | tilichiki
# Processing Record 32 of Set 10 | talcahuano
# Processing Record 33 of Set 10 | kahului
# Processing Record 34 of Set 10 | yanan
# Processing Record 35 of Set 10 | vitimskiy
# Processing Record 36 of Set 10 | la ligua
# Processing Record 37 of Set 10 | saint-georges
# Processing Record 38 of Set 10 | tulsipur
# Processing Record 39 of Set 10 | maniitsoq
# Processing Record 40 of Set 10 | mayo
# Processing Record 41 of Set 10 | gizo
# Processing Record 42 of Set 10 | port keats
# Processing Record 43 of Set 10 | sri aman
# Processing Record 44 of Set 10 | sedelnikovo
# Processing Record 45 of Set 10 | khonuu
# Processing Record 46 of Set 10 | loa janan
# Processing Record 47 of Set 10 | le mars
# Processing Record 48 of Set 10 | anloga
# Processing Record 49 of Set 10 | la asuncion
# Processing Record 50 of Set 10 | mogadishu
# Processing Record 1 of Set 11 | sitka
# Processing Record 2 of Set 11 | hauterive
# Processing Record 3 of Set 11 | bratsk
# Processing Record 4 of Set 11 | presidencia roque saenz pena
# Processing Record 5 of Set 11 | ambulu
# Processing Record 6 of Set 11 | ayagoz
# Processing Record 7 of Set 11 | sanming
# Processing Record 8 of Set 11 | veinticinco de mayo
# Processing Record 9 of Set 11 | samal
# Processing Record 10 of Set 11 | matay
# Processing Record 11 of Set 11 | ginir
# Processing Record 12 of Set 11 | sao filipe
# Processing Record 13 of Set 11 | oranjemund
# Processing Record 14 of Set 11 | gamba
# Processing Record 15 of Set 11 | san ignacio
# Processing Record 16 of Set 11 | opuwo
# Processing Record 17 of Set 11 | catamarca
# Processing Record 18 of Set 11 | sokolka
# Processing Record 19 of Set 11 | durusu
# Processing Record 20 of Set 11 | shakawe
# Processing Record 21 of Set 11 | pasighat
# Processing Record 22 of Set 11 | caldas da rainha
# Processing Record 23 of Set 11 | severo-kurilsk
# Processing Record 24 of Set 11 | hailey
# Processing Record 25 of Set 11 | maraba
# Processing Record 26 of Set 11 | borba
# Processing Record 27 of Set 11 | tigil
# Processing Record 28 of Set 11 | naze
# Processing Record 29 of Set 11 | marapanim
# Processing Record 30 of Set 11 | los llanos de aridane
# Processing Record 31 of Set 11 | kamenskoye
# Processing Record 32 of Set 11 | winslow
# Processing Record 33 of Set 11 | najran
# Processing Record 34 of Set 11 | tautira
# Processing Record 35 of Set 11 | araguaina
# Processing Record 36 of Set 11 | pemangkat
# Processing Record 37 of Set 11 | ajdabiya
# Processing Record 38 of Set 11 | new plymouth
# Processing Record 39 of Set 11 | ambunti
# Processing Record 40 of Set 11 | challans
# Processing Record 41 of Set 11 | matagami
# Processing Record 42 of Set 11 | fevralsk
# Processing Record 43 of Set 11 | buta
# Processing Record 44 of Set 11 | smithers
# Processing Record 45 of Set 11 | yulara
# Processing Record 46 of Set 11 | carutapera
# Processing Record 47 of Set 11 | lasa
# Processing Record 48 of Set 11 | vostok
# Processing Record 49 of Set 11 | shelburne
# Processing Record 50 of Set 11 | kyren
# Processing Record 1 of Set 12 | pudozh
# Processing Record 2 of Set 12 | nantucket
# Processing Record 3 of Set 12 | tromso
# Processing Record 4 of Set 12 | biak
# Processing Record 5 of Set 12 | aracataca
# Processing Record 6 of Set 12 | menongue
# Processing Record 7 of Set 12 | tokoroa
# Processing Record 8 of Set 12 | dubbo
# Processing Record 9 of Set 12 | daly city
# Processing Record 10 of Set 12 | hambantota
# Processing Record 11 of Set 12 | bontang
# Processing Record 12 of Set 12 | say
# Processing Record 13 of Set 12 | filadelfia
# Processing Record 14 of Set 12 | auki
# Processing Record 15 of Set 12 | san juan
# Processing Record 16 of Set 12 | caronport
# Processing Record 17 of Set 12 | mercedes
# Processing Record 18 of Set 12 | lano
# Processing Record 19 of Set 12 | riyadh
# Processing Record 20 of Set 12 | lata
# Processing Record 21 of Set 12 | belmonte
# Processing Record 22 of Set 12 | klaksvik
# Processing Record 23 of Set 12 | wildeshausen
# Processing Record 24 of Set 12 | gobabis
# Processing Record 25 of Set 12 | almaznyy
# Processing Record 26 of Set 12 | bud
# Processing Record 27 of Set 12 | mitsamiouli
# Processing Record 28 of Set 12 | alekseyevsk
# Processing Record 29 of Set 12 | tabou
# Processing Record 30 of Set 12 | ganzhou
# Processing Record 31 of Set 12 | shahrud
# Processing Record 32 of Set 12 | visby
# Processing Record 33 of Set 12 | borovoy
# Processing Record 34 of Set 12 | sault sainte marie
# Processing Record 35 of Set 12 | bandarbeyla
# Processing Record 36 of Set 12 | pacific grove
# Processing Record 37 of Set 12 | vestmannaeyjar
# Processing Record 38 of Set 12 | flin flon
# Processing Record 39 of Set 12 | fare
# Processing Record 40 of Set 12 | nouadhibou
# Processing Record 41 of Set 12 | general roca
# Processing Record 42 of Set 12 | tecozautla
# Processing Record 43 of Set 12 | sampit
# Processing Record 44 of Set 12 | karacabey
# Processing Record 45 of Set 12 | trairi
# Processing Record 46 of Set 12 | mbanza-ngungu
# Processing Record 47 of Set 12 | pochutla
# Processing Record 48 of Set 12 | capao bonito
# Processing Record 49 of Set 12 | hami
# Processing Record 50 of Set 12 | sibut
# Processing Record 1 of Set 13 | sehithwa
# Processing Record 2 of Set 13 | leua
# Processing Record 3 of Set 13 | samarai
# Processing Record 4 of Set 13 | hofn
# Processing Record 5 of Set 13 | nioki
# Processing Record 6 of Set 13 | scottsbluff
# Processing Record 7 of Set 13 | proletarsk
# Processing Record 8 of Set 13 | ambilobe
# Processing Record 9 of Set 13 | sarakhs
# Processing Record 10 of Set 13 | biryukove
# Processing Record 11 of Set 13 | rabo de peixe
# Processing Record 12 of Set 13 | anadyr
# Processing Record 13 of Set 13 | dabola
# Processing Record 14 of Set 13 | pangnirtung
# Processing Record 15 of Set 13 | achisay
# Processing Record 16 of Set 13 | ancud
# Processing Record 17 of Set 13 | aklavik
# Processing Record 18 of Set 13 | moron
# Processing Record 19 of Set 13 | muli
# Processing Record 20 of Set 13 | sabzevar
# Processing Record 21 of Set 13 | aguimes
# Processing Record 22 of Set 13 | xining
# Processing Record 23 of Set 13 | necochea
# Processing Record 24 of Set 13 | waihi beach
# Processing Record 25 of Set 13 | progreso
# Processing Record 26 of Set 13 | havre
# Processing Record 27 of Set 13 | ikom
# Processing Record 28 of Set 13 | turkistan
# Processing Record 29 of Set 13 | linxia
# Processing Record 30 of Set 13 | tigre
# Processing Record 31 of Set 13 | diban
# Processing Record 32 of Set 13 | port augusta
# Processing Record 33 of Set 13 | coxim
# Processing Record 34 of Set 13 | sooke
# Processing Record 35 of Set 13 | rawson
# Processing Record 36 of Set 13 | sassandra
# Processing Record 37 of Set 13 | straumen
# Processing Record 38 of Set 13 | liuzhou
# Processing Record 39 of Set 13 | usinsk
# Processing Record 40 of Set 13 | ewa beach
# Processing Record 41 of Set 13 | luau

# %%
# We have handled request errors for getting the response from a valid city with an API 
# call using conditional statements. Now we’ll learn how to handle errors while parsing 
# weather data from a JSON file.

# We’ll add a "try-except" block to our code to prevent the API request from stopping prematurely 
# if the city_weather request isn't a valid response. If the request isn’t valid, the code will 
# not find the first item requested, which is the dictionary "coord" with the code 
# city_lat = city_weather["coord"]["lat"], and skip the city and continue to run.

# %%
# Let’s add a "try" block. Then, below the try block, do the following:
# Parse the JSON file for the current city
# Assign variables for each piece of data we need.
# Add the data to the cities list in a dictionary format.
# Add the following code after record_count += 1.

# Run an API request for each of the cities.
try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
except:
    print("City not found. Skipping...")
    pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Create a DataFrame of City Weather Data
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#    City    Lat    Lng  Max Temp  Humidity  Cloudiness  Wind Speed Country  \
# 0  Luau -10.71  22.22     64.76        71          93        2.37      AO
# 1  Luau -10.71  22.22     64.76        71          93        2.37      AO
# 2  Luau -10.71  22.22     64.76        71          93        2.37      AO
# 3  Luau -10.71  22.22     64.76        71          93        2.37      AO
# 4  Luau -10.71  22.22     64.76        71          93        2.37      AO
# 5  Luau -10.71  22.22     64.76        71          93        2.37      AO
# 6  Luau -10.71  22.22     64.76        71          93        2.37      AO
# 7  Luau -10.71  22.22     64.76        71          93        2.37      AO
# 8  Luau -10.71  22.22     64.76        71          93        2.37      AO
# 9  Luau -10.71  22.22     64.76        71          93        2.37      AO
#
#                   Date
# 0  2020-03-29 23:02:34
# 1  2020-03-29 23:02:34
# 2  2020-03-29 23:02:34
# 3  2020-03-29 23:02:34
# 4  2020-03-29 23:02:34
# 5  2020-03-29 23:02:34
# 6  2020-03-29 23:02:34
# 7  2020-03-29 23:02:34
# 8  2020-03-29 23:02:34
# 9  2020-03-29 23:02:34

# %%
# Next, we’ll reorder the columns as City, Country, Date, Lat, Lng, Max Temp, Humidity, 
# Cloudiness, and Wind Speed, so they are easy to read.
city_data_df = city_data_df[["City","Country","Date","Lat","Lng","Max Temp","Humidity", "Cloudiness","Wind Speed"]]
city_data_df
# Out:
#    City Country                 Date    Lat    Lng  Max Temp  Humidity  \
# 0  Luau      AO  2020-03-29 23:02:34 -10.71  22.22     64.76        71
# 1  Luau      AO  2020-03-29 23:02:34 -10.71  22.22     64.76        71
# 2  Luau      AO  2020-03-29 23:02:34 -10.71  22.22     64.76        71
# 3  Luau      AO  2020-03-29 23:02:34 -10.71  22.22     64.76        71
# 4  Luau      AO  2020-03-29 23:02:34 -10.71  22.22     64.76        71
# 5  Luau      AO  2020-03-29 23:02:34 -10.71  22.22     64.76        71
# 6  Luau      AO  2020-03-29 23:02:34 -10.71  22.22     64.76        71
# 7  Luau      AO  2020-03-29 23:02:34 -10.71  22.22     64.76        71
# 8  Luau      AO  2020-03-29 23:02:34 -10.71  22.22     64.76        71
#
#    Cloudiness  Wind Speed
# 0          93        2.37
# 1          93        2.37
# 2          93        2.37
# 3          93        2.37
# 4          93        2.37
# 5          93        2.37
# 6          93        2.37
# 7          93        2.37
# 8          93        2.37

# %%
# we’ll create an output file to save the DataFrame as a CSV in a new folder for that file.
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
